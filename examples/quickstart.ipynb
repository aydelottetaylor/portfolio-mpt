# %% [markdown]
# # This is a guide on how to get started with this library!

# %% [markdown]
# To use in a Python notebook, run the following to install from GitHub and test if the library imports correctly:
#
# ```python
# !pip install "git+https://github.com/aydelottetaylor/portfolio-mpt"
#
# import portfolio_mpt as pm
#
# pm.hello()
# ```
